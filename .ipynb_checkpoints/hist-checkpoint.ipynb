# %%
# Use this at the beginning of your script so that your code will be compatible with python3
from __future__ import print_function, division, unicode_literals

from abipy import abilab
abilab.enable_notebook() # This line tells AbiPy we are running inside a notebook
import abipy.data as abidata

# This line configures matplotlib to show figures embedded in the notebook.
# Replace `inline` with `notebook` in classic notebook
# %matplotlib inline   

cwd = '/home/yerin/dfthub/Pt'

# %%
hist = abilab.abiopen(abidata.ref_file(f'{cwd}/Pt_cell_o_HIST.nc'))
print(f'Number of iterations performed: {hist.num_steps}')
# Out:
# Number of iterations performed: 8

# %%
for struct, etot in zip(hist.structures, hist.etotals):
    print("Volume:", struct.volume,", Etotal:", etot)
# Out:
# Volume: 77.84100086228952 , Etotal: -737.3506234117583
# Volume: 76.44905238075373 , Etotal: -737.4260269669633
# Volume: 51.559819775780966 , Etotal: -736.75436124565
# Volume: 69.60837101532239 , Etotal: -737.7397474325974
# Volume: 66.31109899017883 , Etotal: -737.8302087534884
# Volume: 63.21011707208767 , Etotal: -737.8515512910265
# Volume: 63.93910356416653 , Etotal: -737.8534558402089
# Volume: 63.8712434384422 , Etotal: -737.8534772067705

# %%
print(hist.final_structure)
# Out:
# Full Formula (Pt1)
# Reduced Formula: Pt
# abc   :   2.527276   2.527276  10.000000
# angles:  90.000000  90.000000  90.000000
# pbc   :       True       True       True
# Sites (1)
#   #  SP      a    b    c  cartesian_forces
# ---  ----  ---  ---  ---  --------------------
#   0  Pt      0    0    0  [0. 0. 0.] eV ang^-1

# %%
hist.plot(tight_layout=True);

# %%
hist.plot_energies();
